# %%
from random import uniform, randint

from main import pop_gen
from generate_genotype_data import generate_genotype_data

# %%
# 1 locus, 2 alleles (HW equilibrium)

generations=200
growth_rate=0.1
max_drift=0.1
mutation_rate=0.01
carrying_capacity = 20000
bottleneck_yr=None
bottleneck_pop=None
covariance=0

genotype_data = {
    (('A1', 'A1'),) : {'Nm': 250, 'Nf': 250, 'fitness': 1.0},
    (('A1', 'A2'),) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0},
    (('A2', 'A2'),) : {'Nm': 250, 'Nf': 250, 'fitness': 0.9},
}


pop_gen(
    generations,
    genotype_data,
    growth_rate,
    carrying_capacity,
    max_drift,
    mutation_rate,
    bottleneck_yr,
    bottleneck_pop,
    covariance,
)

# %%
# 2 loci with 2 alleles each (Not HW equilibrium)

generations=200
growth_rate=1
drift=0.1
mutation_rate=0.0001
carrying_capacity = 3600
bottleneck_yr=None
bottleneck_pop=None
covariance=-0.5

genotype_data = {
    (('A1', 'A1'), ('B1', 'B1')): {'Nm': 100, 'Nf' : 100, 'fitness' : uniform(0, 1)},
    (('A1', 'A1'), ('B1', 'B2')): {'Nm': 100, 'Nf' : 100, 'fitness' : uniform(0, 1)},
    (('A1', 'A1'), ('B2', 'B2')): {'Nm': 100, 'Nf' : 100, 'fitness' : uniform(0, 1)},
    (('A1', 'A2'), ('B1', 'B1')): {'Nm': 100, 'Nf' : 100, 'fitness' : uniform(0, 1)},
    (('A1', 'A2'), ('B1', 'B2')): {'Nm': 100, 'Nf' : 100, 'fitness' : uniform(0, 1)},
    (('A1', 'A2'), ('B2', 'B2')): {'Nm': 100, 'Nf' : 100, 'fitness' : uniform(0, 1)},
    (('A2', 'A2'), ('B1', 'B1')): {'Nm': 100, 'Nf' : 100, 'fitness' : uniform(0, 1)},
    (('A2', 'A2'), ('B1', 'B2')): {'Nm': 100, 'Nf' : 100, 'fitness' : uniform(0, 1)},
    (('A2', 'A2'), ('B2', 'B2')): {'Nm': 100, 'Nf' : 100, 'fitness' : uniform(0, 1)},
}

mutations = [{('A1', 'A2'): 0.0, ('A2', 'A1'): 0.0,},
             {('B1', 'B2'): 0.0, ('B2', 'B1'): 0.0}]

pop_gen(
    generations,
    genotype_data,
    growth_rate,
    carrying_capacity,
    drift,
    mutation_rate,
    bottleneck_yr,
    bottleneck_pop,
    covariance,
)

# %%
# 1 locus, 3 alleles each (Not HW equilibrium)

generations=200
growth_rate=0.1
drift=0.1
mutation_rate=0.0001
carrying_capacity = 30000
bottleneck_yr=None
bottleneck_pop=500
covariance=0

genotype_data = {
    (('A1', 'A1'),) : {'Nm': 1000, 'Nf': 1000, 'fitness': 0.9},
    (('A1', 'A2'),) : {'Nm': 3000, 'Nf': 3000, 'fitness': 0.95},
    (('A1', 'A3'),) : {'Nm': 500, 'Nf': 500, 'fitness': 0.2},
    (('A2', 'A2'),) : {'Nm': 500, 'Nf': 500, 'fitness': 0.9},
    (('A2', 'A3'),) : {'Nm': 500, 'Nf': 500, 'fitness': 0.6},
    (('A3', 'A3'),) : {'Nm': 20, 'Nf': 20, 'fitness': 1.0},
}

mutations=None

pop_gen(
    generations,
    genotype_data,
    growth_rate,
    carrying_capacity,
    drift,
    mutation_rate,
    bottleneck_yr,
    bottleneck_pop,
    covariance,
)
