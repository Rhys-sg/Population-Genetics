# %%
from main import next_genotype_frequencies
from generate_genotype_data import generate_genotype_data

# %%
# 1 locus, 2 alleles (HW equilibrium)

generations=200
growth_rate=0.1
drift=0
carrying_capacity = 500


genotype_counts = {
    (('A1', 'A1'),): 25,
    (('A1', 'A2'),): 50,
    (('A2', 'A2'),): 25
}

genotype_fitness = {
    (('A1', 'A1'),): 1.0,
    (('A1', 'A2'),): 1.0,
    (('A2', 'A2'),): 0.9
}

mutations = [{('A1', 'A2'): 0.0, ('A2', 'A1'): 0.0,}]

next_genotype_frequencies(generations, genotype_counts, genotype_fitness, growth_rate, carrying_capacity, drift, mutations)
# Out:
# c:\Users\rsore\Documents\GitHub\population-genetics\multiple_loci_multiple_alleles\main.py:105: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# 2 locus, 2 alleles each (Not HW equilibrium)

generations=200
growth_rate=0.1
drift=0
carrying_capacity = 100000


genotype_counts = {
    (('A1', 'A2'), ('B1', 'B1')): 1000,
    (('A1', 'A2'), ('B1', 'B2')): 3000,
    (('A1', 'A2'), ('B2', 'B2')): 1500,
    (('A2', 'A2'), ('B1', 'B1')): 500,
    (('A2', 'A2'), ('B1', 'B2')): 2000,
    (('A2', 'A2'), ('B2', 'B2')): 1000,
    (('A1', 'A1'), ('B1', 'B1')): 500,
    (('A1', 'A1'), ('B1', 'B2')): 1000,
    (('A1', 'A1'), ('B2', 'B2')): 500 
}

genotype_fitness = {
    (('A1', 'A2'), ('B1', 'B1')): 1.0,
    (('A1', 'A2'), ('B1', 'B2')): 1.0,
    (('A1', 'A2'), ('B2', 'B2')): 0.8,
    (('A2', 'A2'), ('B1', 'B1')): 0.8,
    (('A2', 'A2'), ('B1', 'B2')): 0.8,
    (('A2', 'A2'), ('B2', 'B2')): 0.8,
    (('A1', 'A1'), ('B1', 'B1')): 0.8,
    (('A1', 'A1'), ('B1', 'B2')): 0.8,
    (('A1', 'A1'), ('B2', 'B2')): 0.8 
}

mutations = [{('A1', 'A2'): 0.0, ('A2', 'A1'): 0.0,},
             {('B1', 'B2'): 0.0, ('B2', 'B1'): 0.0}]

next_genotype_frequencies(generations, genotype_counts, genotype_fitness, growth_rate, carrying_capacity, drift, mutations)

# %%
# 1 locus, 3 alleles each (Not HW equilibrium)

generations=200
growth_rate=0.1
drift=0
carrying_capacity = 10000

genotype_counts = {
    (('A1', 'A1'),): 1000,
    (('A1', 'A2'),): 3000,
    (('A1', 'A3'),): 500,
    (('A2', 'A2'),): 500,
    (('A2', 'A3'),): 500,
    (('A3', 'A3'),): 2000,
}

genotype_fitness = {
    (('A1', 'A1'),): 0.8,
    (('A1', 'A2'),): 0.8,
    (('A1', 'A3'),): 0.8,
    (('A2', 'A2'),): 0.8,
    (('A2', 'A3'),): 1.0,
    (('A3', 'A3'),): 0.1,
}

mutations=None

next_genotype_frequencies(generations, genotype_counts, genotype_fitness, growth_rate, carrying_capacity, drift, mutations)

# %%
# 2 locus, 3 alleles each (Randomly generated, not HW equilibrium)

generations=200
growth_rate=0.1
drift=0
carrying_capacity = 10000


num_loci = 2
num_alleles = 3
population_size = 10000
random_seed = 0
genotype_counts, genotype_fitness = generate_genotype_data(num_loci, num_alleles, population_size, random_seed)

# print("Genotype Counts:")
# for genotype, count in genotype_counts.items():
#     print(f"{genotype}: {count}")

# print("\nGenotype Fitness:")
# for genotype, fitness in genotype_fitness.items():
#     print(f"{genotype}: {fitness}")

mutations=None

next_genotype_frequencies(generations, genotype_counts, genotype_fitness, growth_rate, carrying_capacity, drift, mutations)
