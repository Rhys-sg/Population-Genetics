# %%
from random import uniform, randint

from generate_genotype_data import generate_genotype_data
from pop_gen import pop_gen

# %%
pg = pop_gen()
pg.genotype_data = {
    (('A1', 'A1'),) : {'Nm': 250, 'Nf': 250, 'fitness': 1.0, 'covariance': 0.1},
    (('A1', 'A2'),) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0, 'covariance': 0.1},
    (('A2', 'A2'),) : {'Nm': 250, 'Nf': 250, 'fitness': 1.0, 'covariance': 0.1},
}
pg.growth_rate = 1.1
pg.growth_rate=0.1
pg.mutation_rate=0.01
pg.carrying_capacity = 20000
pg.max_drift=0.1

pg.run(200)
pg.plot_genotype_counts()
pg.plot_genotype_frequencies()
pg.plot_allele_counts()
pg.plot_allele_frequencies()
pg.plot_population_sizes()
pg.plot_effective_population_sizes()
pg.plot_average_fitness()

# %%
pg = pop_gen()
pg.genotype_data = {
    (('A1', 'A1'),) : {'Nm': 250, 'Nf': 250, 'fitness': 1.0, 'covariance': 0},
    (('A1', 'A2'),) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0, 'covariance': 0},
    (('A1', 'A3'),) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0, 'covariance': 0},
    (('A2', 'A2'),) : {'Nm': 250, 'Nf': 250, 'fitness': 0.9, 'covariance': 0},
    (('A2', 'A3'),) : {'Nm': 500, 'Nf': 500, 'fitness': 0.9, 'covariance': 0},
    (('A3', 'A3'),) : {'Nm': 250, 'Nf': 250, 'fitness': 0.8, 'covariance': 0},

}
pg.growth_rate = 1.1
pg.growth_rate=0.1
pg.mutation_rate=0.01
pg.carrying_capacity = 20000
# pg.max_drift=0.5
pg.covariance=0

pg.run(200)
# pg.run(100, bottleneck_yr=50, bottleneck_N=1000)
pg.plot_genotype_counts()
pg.plot_genotype_frequencies()
pg.plot_allele_counts()
pg.plot_allele_frequencies()
pg.plot_population_sizes()
pg.plot_effective_population_sizes()
pg.plot_average_fitness()

# %%
pg = pop_gen()

pg.genotype_data = {
    (('A1', 'A1'), ('B1', 'B1')) : {'Nm': 250, 'Nf': 250, 'fitness': 1.0, 'covariance': 0},
    (('A1', 'A1'), ('B1', 'B2')) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0, 'covariance': 0},
    (('A1', 'A1'), ('B2', 'B2')) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0, 'covariance': 0},
    (('A1', 'A2'), ('B1', 'B1')) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0, 'covariance': 0},
    (('A1', 'A2'), ('B1', 'B2')) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0, 'covariance': 0},
    (('A1', 'A2'), ('B2', 'B2')) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0, 'covariance': 0},
    (('A2', 'A2'), ('B1', 'B1')) : {'Nm': 250, 'Nf': 250, 'fitness': 0.9, 'covariance': 0},
    (('A2', 'A2'), ('B1', 'B2')) : {'Nm': 500, 'Nf': 500, 'fitness': 0.9, 'covariance': 0},
    (('A2', 'A2'), ('B2', 'B2')) : {'Nm': 250, 'Nf': 250, 'fitness': 0.9, 'covariance': 0},
}
pg.growth_rate = 1.1
pg.growth_rate=0.1
pg.mutation_rate=0.01
pg.carrying_capacity = 20000
# pg.max_drift=0.5
pg.covariance=0

pg.run(200)
# pg.run(100, bottleneck_yr=50, bottleneck_N=1000)
pg.plot_genotype_counts()
pg.plot_genotype_frequencies()
pg.plot_allele_counts()
pg.plot_allele_frequencies()
pg.plot_population_sizes()
pg.plot_effective_population_sizes()
pg.plot_average_fitness()

# %%
pg = pop_gen()

pg.genotype_data = {
    (('A1', 'A1'), ('B1', 'B1')) : {'Nm': 250, 'Nf': 250, 'fitness': 1.0, 'covariance': 0},
    (('A1', 'A1'), ('B1', 'B2')) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0, 'covariance': 0},
    (('A1', 'A1'), ('B2', 'B2')) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0, 'covariance': 0},
    (('A1', 'A2'), ('B1', 'B1')) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0, 'covariance': 0},
    (('A1', 'A2'), ('B1', 'B2')) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0, 'covariance': 0},
    (('A1', 'A2'), ('B2', 'B2')) : {'Nm': 500, 'Nf': 500, 'fitness': 1.0, 'covariance': 0},
    (('A2', 'A2'), ('B1', 'B1')) : {'Nm': 250, 'Nf': 250, 'fitness': 0.9, 'covariance': 0},
    (('A2', 'A2'), ('B1', 'B2')) : {'Nm': 500, 'Nf': 500, 'fitness': 0.9, 'covariance': 0},
    (('A2', 'A2'), ('B2', 'B2')) : {'Nm': 250, 'Nf': 250, 'fitness': 0.9, 'covariance': 0},
}
